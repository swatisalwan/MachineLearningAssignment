# %%
import pandas as pd
import numpy as np
import seaborn as sns
from datetime import datetime 
from sklearn import metrics
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('problem_2_train.csv')
X=data.iloc[:,0:15]
#X.head()
Y=data['tat_in_days']

data.dtypes
#data['claimtype'].unique()
X=X.drop(columns=['srno','pickuppartnerid','deliverypartnerid','insuranceCompanyId','claimtype','memcreateddate','mobilepurchasedate','claimintdate','servicecntrid'])

# %%
data[data.notnull()]
# Out:
#          srno mobmake  hubid  hubpincode  pickuppartnerid  deliverypartnerid  \
# 0     2851218      AN      7      500004              233                233
# 1     2838330      AJ     10      226010              233                233
# 2     2835781      AJ      2      110018              233                233
# 3     2838589      AM      2      110018              233                233
# 4     2855214      AN     21      110015              233                233
# 5     2852784      AN     21      110015              233                233
# 6     2844713       C      2      110018              233                233
# 7     2829719       C      6      160059              233                233
# 8     2833619      AN      3      560011              201                233
# 9     2870579      AJ      5      380009              233                233
# 10    2851462      AN      3      560011              233                233
# 11    2864593      AN     22      400104              233                233
# 12    2902016       C      2      110018              233                233
# 13    2891631      AI      8      700064              233                233
# 14    2926054      AD      4      600024              233                233
# 15    2899949       S      2      110018              308                233
# 16    2969907      AJ     12      302006              233                233
# 17    2906122      AN     21      110015              233                233
# 18    2932008       C      2      110018              233                233
# 19    2970930      AJ      2      110018              233                233
# 20    2866366      AJ      2      110018              233                233
# 21    2905985      AD      3      560011              233                233
# 22    2908451      AD      2      110018              233                233
# 23    2979013      AN     22      400104              233                233
# 24    2920951      AN     26      560066              233                233
# 25    2982966       C      2      110018              308                233
# 26    2970294      AN     22      400104              233                233
# 27    2958255      AA     24      110092              233                233
# 28    2974060      AM      2      110018              233                233
# 29    3022644      AJ     27      110034              233                233
# ...       ...     ...    ...         ...              ...                ...
# 6220  2972006       S     24      110092              233                233
# 6221  3065218      AN     21      110015              233                233
# 6222  3012962      AN     26      560066              233                245
# 6223  2909668      AJ      1      400059              233                233
# 6224  2973482       D      1      400059              233                233
# 6225  3038101      AN     17      800001              233                233
# 6226  2929016       C      3      560011              233                245
# 6227  3049731       C      3      560011              233                245
# 6228  2884305      AN     21      110015              233                233
# 6229  2954084      AN     21      110015              233                233
# 6230  2994106      AJ     27      110034              233                233
# 6231  2984042      AN     22      400104              233                  0
# 6232  3029536      AN     26      560066              233                233
# 6233  2962519      AM      1      400059              233                245
# 6234  2844945      AN      4      600024              233                233
# 6235  2824988       C      7      500004              233                233
# 6236  2838265       H      2      110018              233                233
# 6237  2863341      AJ     12      302006              233                233
# 6238  2939451       C      1      400059              233                233
# 6239  2930645      AN     21      110015              233                233
# 6240  3016763      AN     26      560066              233                233
# 6241  2981238      AN      8      700064              233                233
# 6242  3072593       C      8      700064              233                233
# 6243  2830968      AN     17      800001              201                201
# 6244  2863463      AK      1      400059              233                233
# 6245  2949680      AJ      2      110018              233                233
# 6246  2971901      AD      1      400059              233                233
# 6247  2999232       C      2      110018              233                233
# 6248  2980326       L      2      110018              233                233
# 6249  2973922      AJ      2      110018              308                233
#
#       insuranceCompanyId custpincodecategory claimtype  custpincode  \
# 0                    131                   A      ADLD       500001
# 1                    131                   A      ADLD       226022
# 2                    228                   A      ADLD       110018
# 3                    228                   B      ADLD       124001
# 4                    131                   A      ADLD       201301
# 5                    131                   B      ADLD       132001
# 6                    131                   A      ADLD       110059
# 7                    131                   B      ADLD       151001
# 8                    131                   A      ADLD       560076
# 9                    131                   B      ADLD       390006
# 6230      2018-03-24           16
# 6231      2018-03-19           18
# 6232      2018-04-19            9
# 6233      2018-03-17           19
# 6234      2018-02-13            6
# 6235      2018-02-07           11
# 6236      2018-02-05           21
# 6237      2018-02-13           20
# 6238      2018-03-07            8
# 6239      2018-03-10           16
# 6240      2018-03-29           10
# 6241      2018-04-01           10
# 6242      2018-04-12           16
# 6243      2018-02-10           16
# 6244      2018-02-13           31
# 6245      2018-03-10           10
# 6246      2018-03-18           10
# 6247      2018-03-22            8
# 6248      2018-03-18           11
# 6249      2018-03-23           10
#
# [6250 rows x 16 columns]

# %%
#Data Preprocessing
#X["memcreateddate"]=pd.to_datetime(X.memcreateddate)
X.dtypes
#X["claimintdate"]=pd.to_datetime(X.claimintdate)
X["pickupStartdate"]=pd.to_datetime(X.pickupStartdate)
#X["mobilepurchasedate"]=pd.to_datetime(X.mobilepurchasedate)

#X['memcreateddate'] = data['memcreateddate'].astype(int)
#X['claimintdate']=X['claimintdate'].map(datetime.toordinal)
X['pickupStartdate']=X['pickupStartdate'].map(datetime.toordinal)
#X['mobilepurchasedate']=X['mobilepurchasedate'].map(datetime.toordinal)
#X['memcreateddate']=X['memcreateddate'].map(datetime.toordinal)
X.dtypes
# Out:
# mobmake                object
# hubid                   int64
# hubpincode              int64
# custpincodecategory    object
# custpincode             int64
# pickupStartdate         int64
# dtype: object

# %%
#Categorical Data
from sklearn.preprocessing import LabelEncoder,OneHotEncoder
labelencoder_X=LabelEncoder()
X['mobmake']=labelencoder_X.fit_transform(X['mobmake'])
X['custpincodecategory']=labelencoder_X.fit_transform(X['custpincodecategory'])
#X['claimtype']=labelencoder_X.fit_transform(X['claimtype'])
#X['claimtype']=labelencoder_X.fit_transform(X['claimtype'])

#onehotencoder=OneHotEncoder(categorical_features=X['claimtype'])
#X=onehotencoder.fit_transform(X).toarray()


#labelencoder_Y=LabelEncoder()
#y=labelencoder_Y.fit_transform(Y)

#sns.pairplot(data,x_vars=['mobmake'],y_vars='tat_in_days',size=7,aspect=0.7,kind='reg')

# %%
X.dtypes
# Out:
# mobmake                int64
# hubid                  int64
# hubpincode             int64
# custpincodecategory    int64
# custpincode            int64
# pickupStartdate        int64
# dtype: object

# %%
#splitting dataset
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.5,random_state=0)
X.dtypes
# Out:
# mobmake                int64
# hubid                  int64
# hubpincode             int64
# custpincodecategory    int64
# custpincode            int64
# pickupStartdate        int64
# dtype: object

# %%
X_train
# Out:
#       mobmake  hubid  hubpincode  custpincodecategory  custpincode  \
# 1980        8     25      560037                    1       560084
# 399        12     21      110015                    1       302012
# 3048        7     27      110034                    1       226001
# 2692        8      1      400059                    1       400093
# 554        11      1      400059                    2       395010
# 3558       17      1      400059                    1       400069
# 5184       12     21      110015                    2       125001
# 4032       31      2      110018                    1       110037
# 3456       12      2      110018                    2       244713
# 2509       17      2      110018                    1       121002
# 5221       12     21      110015                    2       134109
# 2693       12      3      560011                    1       560100
# 5076        5      5      380009                    1       380055
# 1812       12     21      110015                    1       110029
# 5493        8      6      160059                    2       144001
# 2947       12     21      110015                    3       143001
# 4592       31      1      400059                    1       401101
# 386         8      6      160059                    2       134109
# 5595       12     22      400104                    2       363001
# 5483       12      7      500004                    1       500028
# 2171       12      3      560011                    4       680009
# 4433       17      8      700064                    1       711101
# 409         8     27      110034                    1       110092
# 1451        7      8      700064                    2       781019
# 5513       12     26      560066                    1       560021
# 191        12     22      400104                    1       400075
# 4670       12     26      560066                    1       560072
# 3629       12      8      700064                    3       751005
# 361         8      2      110018                    1       110095
# 200        12     22      400104                    1       411045
# ...       ...    ...         ...                  ...          ...
# 2008       12      3      560011                    1       560103
# 99         17      9      411016                    2       440030
# 2496       23      2      110018                    1       122001
# 1871       17     12      302006                    3       331022
# 2046        8     25      560037                    1       600007
# 4851        8      5      380009                    1       380001
# 5072       11      7      500004                    3       530047
# 2163       12      8      700064                    2       732103
# 6036        8      2      110018                    1       201006
# 6216       12      7      500004                    2       533005
# 2893        8      2      110018                    1       110031
# 537        17      7      500004                    1       500017
# 1701       12     21      110015                    1       110010
# 2897        7     23      400001                    2       462001
# 2222       12     22      400104                    1       421306
# 2135       31     24      110092                    1       411001
# 2599       12      3      560011                    1       560049
# 705        17      8      700064                    3       751007
# 3468       12      3      560011                    1       560062
# 5924        8      7      500004                    1       500001
# 5874        8     27      110034                    1       121004
# 4373        8     27      110034                    1       110076
# 1033       12     22      400104                    1       411038
# 5827        8      2      110018                    1       110017
# 4859       21      1      400059                    1       411027
# 4931        3      6      160059                    3       171009
# 3264       12     26      560066                    1       560037
# 1653       12     21      110015                    1       110040
# 2607        8      3      560011                    2       590006
# 2732       17     10      226010                    1       226010
#
#       pickupStartdate
# 1980           736786
# 399            736773
# 3048           736783
# 2692           736754
# 554            736794
# 3558           736747
# 5184           736755
# 4032           736737
# 3456           736728
# 2509           736751
# 5221           736784
# 2693           736754
# 5076           736735
# 1812           736758
# 5493           736755
# 2947           736791
# 4592           736756
# 386            736753
# 5595           736749
# 5483           736746
# 2171           736779
# 4433           736780
# 409            736789
# 1451           736781
# 5513           736795
# 191            736744
# 4670           736798
# 3629           736737
# 361            736754
# 200            736766
# ...               ...
# 2008           736740
# 99             736747
# 2496           736792
# 1871           736786
# 2046           736807
# 4851           736747
# 5072           736758
# 2163           736801
# 6036           736752
# 6216           736751
# 2893           736767
# 537            736799
# 1701           736756
# 2897           736768
# 2222           736753
# 2135           736771
# 2599           736733
# 705            736789
# 3468           736740
# 5924           736802
# 5874           736788
# 4373           736784
# 1033           736755
# 5827           736747
# 4859           736756
# 4931           736730
# 3264           736779
# 1653           736788
# 2607           736755
# 2732           736777
#
# [3125 rows x 6 columns]

# %%
corr=data.corr()
sns.heatmap(corr)

# %%
X.shape
# Out:
# (6250, 6)

# %%
# from sklearn.preprocessing import Imputer
# imputer =Imputer(missing_values=0,strategy='mean',axis=1)
# imputer=imputer.fit(X)
# X=imputer.transform(X)

# %%
from sklearn.preprocessing import StandardScaler
sc_X=StandardScaler()
X_train=sc_X.fit_transform(X_train)
X_test=sc_X.fit_transform(X_test)
X_train
# Out:
# array([[-0.71154577,  1.46812831,  1.00980757, -0.53983005,  0.90013027,
#          1.00720261],
#        [-0.02957045,  1.02885302, -1.08698762, -0.53983005, -0.314067  ,
#          0.38508976],
#        [-0.8820396 ,  1.68776595, -1.08689909, -0.53983005, -0.67168947,
#          0.8636381 ],
#        ...,
#        [-0.02957045,  1.02885302, -1.08698762, -0.53983005, -1.21727182,
#          1.10291227],
#        [-0.71154577, -0.94788579,  1.00968643,  0.72666313,  1.04090962,
#         -0.47629725],
#        [ 0.8228987 , -0.17915403, -0.54653013, -0.53983005, -0.67164713,
#          0.5765091 ]])

# %%
#Simple Linear Regression
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,Y_train)

Y_pred=regressor.predict(X_test)
print(np.sqrt(metrics.mean_squared_error(Y_test,Y_pred)))
#list(zip(X,regressor.coef_))

# plt.scatter(X['pickuppartnerid'],Y_train,color='red')
# plt.plot(X_train,Y_pred,color='blue')
# plt.show()
# Out:
# 4.80654642497784

# %%
#Multiple Linear Regression
#Backward Elimination
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(X_train,Y_train)

Y_pred=regressor.predict(X_test)

print(np.sqrt(metrics.mean_squared_error(Y_test,Y_pred)))
#Backward elimination
#import statsmodels.formula.api as sm
# x=np.append(arr=np.ones(50,1).astype(int),values=X,axis=1)

# X_opt=X[:,[0,1,2,3,4,5]]
# regressor_OLS=sm.OLS(endog=Y,exog=X_opt).fit()
# regressor_OLS.summary()
# Out:
# 4.80654642497784

# %%
#Polynomial Regression
# from sklearn.preprocessing import PolynomialFeatures
# from sklearn.linear_model import LinearRegression
# regressor=PolynomialFeatures(degree=2)
# X_poly=regressor.fit_transform(X_train)
# lin_reg=LinearRegression()
# lin_reg.fit(X_poly,Y_train)
# Y_pred=lin_reg.predict(X_test)
# #Y_pred=regressor.predict(X_test)
# print(np.sqrt(metrics.mean_squared_error(Y_test,Y_pred)))

# %%
#Support vector regression
from sklearn.svm import SVR
regressor=SVR(kernel='rbf')
regressor.fit(X_train,Y_train)
#do feature scaling

#Y_pred=regressor.predict(sc_X.transform(np.array([[6.5]])))
Y_pred=regressor.predict(X_test)

#do inverse scaling
#Y_pred=sc_Y.inverse_transform(...)
print(np.sqrt(metrics.mean_squared_error(Y_test,Y_pred)))
# Out:
# 4.494123952314891

# %%
#Decision tree regression
from sklearn.tree import DecisionTreeRegressor
regressor=DecisionTreeRegressor(random_state=0)
regressor.fit(X_train,Y_train)
print(np.sqrt(metrics.mean_squared_error(Y_test,Y_pred)))
# Out:
# 4.494123952314891

# %%
#Random forest regression
from sklearn.ensemble import RandomForestRegressor
regressor=RandomForestRegressor(n_estimators=10,random_state=0)
regressor.fit(X,Y)

print(np.sqrt(metrics.mean_squared_error(Y_test,Y_pred)))
# Out:
# C:\Users\AA\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# 4.494123952314891

# %%
#R-squared
#adj R-squared
#more adj r2 is good

# %%
#X-fold cross technique

# %%
#feature_cols=['hubpincode','hubid','pickuppartnerid','']

#list(zip(X,regressor.coef_))

# %%
print(np.sqrt(metrics.mean_squared_error(Y_test,Y_pred)))
# Out:
# 4.494123952314891

# %%
import statsmodels.formula.api as sm
# x=np.append(arr=np.ones(6250,1).astype(int),values=X,axis=1)

# X_opt=X[:,[0,1,2,3,4,5]]
# regressor_OLS=sm.OLS(endog=Y,exog=X_opt).fit()
# regressor_OLS.summary()

# %%
X_test
# Out:
# array([[-0.70889457, -0.96275689,  1.04726435, -0.55715846,  0.94009837,
#         -1.3404388 ],
#        [ 1.46280002, -0.96275689,  1.04726435, -0.55715846,  0.94008882,
#         -0.19529966],
#        [-0.04068085,  0.56324173,  2.17823812,  0.71559021,  2.10098381,
#          1.09298187],
#        ...,
#        [ 1.79690688, -1.0717568 , -1.07336685, -0.55715846, -1.20928912,
#         -1.19729641],
#        [-0.04068085, -0.85375699,  1.23582909, -0.55715846,  1.13127297,
#         -0.76786923],
#        [-0.54184114, -1.0717568 , -1.07336685,  0.71559021,  0.1278201 ,
#          0.32955578]])
